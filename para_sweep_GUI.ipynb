# %%
# %matplotlib notebook
#!pip install ipyupload
from IPython.display import display,HTML
import codes.GUI as GUI
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
# %%html
# <style>
# .jupyter-widgets.widget-tab > .p-TabBar .p-TabBar-tab {
#     flex: 0 1 175px
# }
# </style>
# Out:
# <style>
# .jupyter-widgets.widget-tab > .p-TabBar .p-TabBar-tab {
#     flex: 0 1 175px
# }
# </style>

# %%
display(GUI.gui)
# Out:
# VBox(children=(Tab(children=(VBox(children=(HBox(children=(BoundedIntText(value=2, description='How many SSH c…
# [Errno 2] No such file or directory: 'run-config\\confinement_20190710_12_48_03_310281.json'
